# %% [markdown]
# <a href="https://colab.research.google.com/github/jeesperon/EjerciciosMNA/blob/main/An%C3%A1lisis_CLUES_FILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
clues = "/content/drive/MyDrive/ESTABLECIMIENTO_SALUD_202208 --- clues.xlsx - dataBase_Clues.csv"
df = pd.read_csv(clues)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (53,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    ID        CLUES CLAVE DE LA INSTITUCION  NOMBRE DE LA UNIDAD  \
# 0   2  ASDIF000011                     DIF   DIF AGUASCALIENTES
# 1   3  ASDIF000023                     DIF            DIF COSÍO
# 2   4  ASDIF000035                     DIF  DIF RINCÓN DE ROMOS
# 3   5  ASDIF000040                     DIF         DIF TEPEZALÁ
# 4   6  ASDIF000052                     DIF         DIF CALVILLO
#
#   TIPO DE VIALIDAD                         VIALIDAD NUMERO EXTERIOR  \
# 0              NaN  MAHATMA GANDHI ESQUINA PARAGUAY             NaN
# 1              NaN                          HIDALGO              42
# 2              NaN                   ÁLVARO OBREGÓN             320
# 3              NaN                           JUÁREZ               3
# ...

# %%
df.dtypes
# Out:
# ID                            int64
# CLUES                        object
# CLAVE DE LA INSTITUCION      object
# NOMBRE DE LA UNIDAD          object
# TIPO DE VIALIDAD             object
#                              ...
# CLAVE DE LA ENTIDAD           int64
# CLAVE DEL MUNICIPIO           int64
# CLAVE DE LA LOCALIDAD         int64
# CLAVE DE LA JURISDICCION      int64
# CLAVE DE VIALIDAD           float64
# Length: 83, dtype: object

# %%
print(df.describe())
# Out:
#                  ID  CODIGO POSTAL  CLAVE TIPO ESTABLECIMIENTO    CLAVE SCIAN  \
# count  42105.000000   41988.000000                42105.000000   14007.000000
# mean   29574.681059   62774.324807                    1.304239  660365.742914
# std    22520.032519   27439.065665                    0.661118  115239.125456
# min        1.000000    1000.000000                    1.000000  621111.000000
# 25%    12138.000000   39715.000000                    1.000000  621112.000000
# 50%    24684.000000   64730.000000                    1.000000  621112.000000
# 75%    36460.000000   87049.250000                    1.000000  621399.000000
# max    79015.000000   99999.000000                    4.000000  999999.000000
#
#        CONSULTORIOS DE MED GRAL  CONSULTORIOS EN OTRAS AREAS  \
# count              42105.000000                 42105.000000
# mean                   2.046432                     0.783066
# std                    6.400476                     6.072544
# ...

# %%
print(df.describe(include=['object']))
# Out:
#               CLUES CLAVE DE LA INSTITUCION  NOMBRE DE LA UNIDAD  \
# count         42105                   42105                42105
# unique        42105                      17                33246
# top     ASDIF000011                     SSA  FARMACIAS SIMILARES
# freq              1                   19821                 4285
#
#        TIPO DE VIALIDAD            VIALIDAD NUMERO EXTERIOR NUMERO INTERIOR  \
# count             25568               42056           24277           11609
# unique               28               17724            5720             431
# top               CALLE  DOMICILIO CONOCIDO     SIN NUMERO       SIN NUMERO
# freq              16265                4227            3614            4988
#
#        TIPO DE ASENTAMIENTO ASENTAMIENTO NOMBRE DE LA ENTIDAD  ...  \
# count                 22011        31891                42105  ...
# unique                   46        14953                   32  ...
# ...

# %%
Descr_1 = df['CLAVE DE LA INSTITUCION'].value_counts().to_frame()
Descr_1.rename(columns={'CLAVE DE LA INSTITUCION': 'value_counts'}, inplace=True)
Descr_1
# Out:
#                 value_counts
# SSA                    19821
# SMP                    12652
# IMSS-BIENESTAR          4522
# IMSS                    1768
# ISSSTE                  1232
# DIF                      709
# SME                      480
# SEDENA                   310
# CRO                      150
# SMM                      145
# PEMEX                     65
# CIJ                       64
# HUN                       45
# SCT                       43
# SEMAR                     39
# PGR                       36
# FGE                       24

# %%
Descr_2 = df['NOMBRE DE LA UNIDAD'].value_counts().to_frame()
Descr_2.rename(columns={'NOMBRE DE LA UNIDAD': 'value_counts'}, inplace=True)
Descr_2
# Out:
#                                                     value_counts
# FARMACIAS SIMILARES                                         4285
# FARMACIAS BENAVIDES                                          459
# FUNDACION BEST A.C.                                          126
# COMERCIALIZADORA FARMACEUTICA DE CHIAPAS SAPI D...           107
# COMERCIALIZADORA FARMACEUTICA DE CHIAPAS S.A.P....            70
# ...                                                          ...
# SAN ANDRÉS TIANGUISTENGO                                       1
# HUAXTHO                                                        1
# DAJIEDHI                                                       1
# CHICAVASCO                                                     1
# UNEME DE ENFERMEDADES CRONICAS RÍO GRANDE                      1
#
# [33246 rows x 1 columns]
